# %%
# -----------------------------
# Cybersecurity RAG Project Setup
# -----------------------------

# Step 1: Install necessary libraries
print("Installing required libraries...")
get_ipython().system('pip install -q --upgrade --force-reinstall langchain langchain-openai openai langchain-chroma chromadb gradio python-dotenv langchain-text-splitters tiktoken langchain-community')
print("Libraries installed successfully!")
# Out:
# Installing required libraries...
# Libraries installed successfully!

# %%
# Step 2: OpenAI client setup
get_ipython().system('pip install -q --upgrade openai')
from openai import OpenAI
import os
from dotenv import load_dotenv

load_dotenv()
cyber_api_key = os.getenv("OPENAI_API_KEY")
cyber_openai_client = OpenAI(api_key=cyber_api_key)
print("\nOpenAI client successfully configured for Cybersecurity RAG.")
print(cyber_api_key[:15])
# Out:
# OpenAI client successfully configured for Cybersecurity RAG.
# sk-proj-p_ArOp0

# %%
# LLM + Embeddings
from langchain_openai import OpenAI, OpenAIEmbeddings

# Vector store
from langchain_chroma import Chroma

# Text splitters
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Document loaders
from langchain_community.document_loaders import TextLoader, PyPDFLoader

# Chains (still in main langchain)
from langchain_classic.chains import RetrievalQAWithSourcesChain
print("Langchain and Chroma imported successfully")
# Out:
# Langchain and Chroma imported successfully

# %%
pip show langchain
